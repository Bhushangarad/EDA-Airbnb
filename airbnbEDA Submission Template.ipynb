# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Bhushan Garad
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# 1.Importing Libraries
#
# 2.Loading the dataset
#
# 3.Data Cleaning:
#
# Dropping duplicates.
# Cleaning individual columns.
# Remove the Null values from the dataset
# Some Transformations
#
# 4.Data Analysis and Visualization: Using plots to find relations between the features
#
# What is the average preferred price by customers according to the location?
#
# Number of active hosts per location (Where most of the hosts focused to own property?)
#
# Where the customer pays the highest and lowest rent according to location?
#
# Most popular/demanded host of Airbnb in New York
#
# Find the total count of each room type
#
# Room types and their relation with availability in different neighbourhood groups
#
# Which are the top 25 most used words in listing names?
#
# Find top 10 hosts with most listings
#
# Find the top three hosts based on their turnover
#
# Find total no. of nights spend per location
#
# Total no. of nights spends per room types
#
# Top 10 highest listing neighborhood

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Bhushangarad/EDA-Airbnb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To find how we will increase our bussiness and where we need to change in our bussiness

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
#importing necessery libraries for future analysis of the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import datetime as dt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# mounting the google drive for connecting to database
from google.colab import drive
drive.mount('/content/drive')
# this function for reading data or for providing path to reach at perticular folder where data is stored
df = pd.read_csv("/content/drive/MyDrive/Capstone Project EDA - Airbnb/AB_NYC_2019.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(df.isnull(), cbar=False)

# %%
df.loc[df.number_of_reviews==0, 'reviews_per_month'] = 0
df.loc[df.number_of_reviews==0, 'last_review'] = 0

# %%
df

# %%
# Removing null values in name and host_name fields
df = df[pd.notnull(df['name'])]
df = df[pd.notnull(df['host_name'])]

# %%
# Recheck the number of nulls in each field
df.isnull().sum()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This is data of Airbnb newyork. containing the 48895 rows and 16 columns ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365'

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe(include='all')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# dataset = df

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
variables_df = df.columns.to_list()
for i in variables_df:
  print('The Unique Values of', i, 'are:', df[i].unique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
numerical_columns=[]
for col in df.columns:
  if df[col].nunique()>5:
    numerical_columns.append(col)
categorical_columns=list(set(df.columns)-set(numerical_columns))

# %%
print(numerical_columns)

# %%
df.sort_values(by=['latitude'])

# %%
df.sort_values(by=['longitude'])

# %%
df.sort_values(by=['price'])

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
a=df.groupby(by=['room_type']).number_of_reviews.sum()
a = a.sort_values(ascending=False)
print(a)

# %%
a.plot(kind='pie')


# show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find how many type of rooms are their

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that the Entire Home/Apartment has the highest share, followed by the Private Room, and the least preferred is Shared Room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as per above chart the entire home apartment and private room has more demand as compare to shared room so we need to get more focuse on shared room

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.style.use('fivethirtyeight')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group")
g = plt.pie(df.neighbourhood_group.value_counts(), labels=df.neighbourhood_group.value_counts().index,autopct='%1.1f%%', startangle=180)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  To explore our data and visualize it to recognize the relationship between the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart above shows that Airbnb Listings in Newyork are near Manhattan, and Brooklyn has the highest share of hotels. We also know that from this map of Neighborhood Group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# manhatten is the neighbourhood which is more rooms and it is most crowded area in newyork

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(13, 7))
plt.title("Room Type on Neighbourhood Group")

# Create a count plot with 'neighbourhood_group' on the x-axis and 'room_type' as the hue
sns.countplot(data=df, x='neighbourhood_group', hue='room_type', palette="muted")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find which neighbourhood group contain which type of room  occupied by a neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph shows that the Entire Home/Apartment is listed most near Manhattan, while Private Rooms and Apartments Near Brooklyn are Nearly equal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group vs. Availability Room")
sns.boxplot(data=df, x='neighbourhood_group',y='availability_365',palette="dark")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find relationship between the availability room and neighborhood group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph above shows the relationship between the availability room and neighborhood group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Which neighbourhood_group is the most expensive?
a=df.groupby(by=['neighbourhood_group']).price.mean()
a = a.sort_values(ascending=False)
print(a)

# %%
df.groupby(by=['neighbourhood_group']).price.mean().plot(kind='bar')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find which neighnourhood group is most expensive

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The information we got from the graph above is we can see that the Manhattan region has a more expensive room price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.style.use('classic')
plt.figure(figsize=(13,7))
plt.title("Neighbourhood Group Price Distribution < 500")
sns.boxplot(y="price",x ='neighbourhood_group' ,data = df[df.price<500])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check price distribution between different neighbourhood group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the boxplot above, we can definitely observe a couple of things about the distribution of prices for Airbnb in NYC.
#
# We can state that Manhattan has the highest range price for the listings with about $140 as an average price, followed by Brooklyn with $90 per night,
# Queens and Staten Island seem to have a very similar distribution,
# The Bronx is the cheapest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Which host_name is the most popular hosts between customers?
a=df.groupby(by=['host_name']).calculated_host_listings_count.mean()
a = a.sort_values(ascending=False)
print(a)

# %%
# obtain a bar chart of the proportion of Airbnb listings in five boroughs
(df.neighbourhood_group.value_counts()/df.shape[1]).plot.bar(cmap='Blues_r',title='Proportion of Airbnb listings across boroughs')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check Which host_name is the most popular hosts between customers?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# manhattan is the 1st preferance of customer and after that brooklyn as shown in graph

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as per customer the manhatten is most popular host so we can shares their experiance to other host to increase their popularity and bussiness

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Availability according to different room_type in different areas
fig = sns.catplot(x='neighbourhood_group',y='availability_365',kind='box',hue='room_type',data=df,palette='pastel')
fig.fig.suptitle('Where is the most popular area?',fontsize=15,y=1.05)
fig.savefig('popular_area.png', bbox_inches = 'tight')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  To check Availability according to different room_type in different areas

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# as per the above chart the queens is the host that mostly available rooms 365 days

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as per the above chart the demand of private room and home appartment only on holidays and weekend as comapared to shared room

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Price according to different room_type in different areas
fig2 = sns.catplot(x='neighbourhood_group',y='price',data=df,kind='bar',hue='room_type',palette='pastel')
fig2.fig.suptitle('Where is the most expensive area?',fontsize=15,y=1.05)
fig2.savefig('price_area.png', bbox_inches = 'tight')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to find Price according to different room_type in different areas

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As per catplot shown above entire home apartment is more expensive in any area as compare to private room and shared room. manhatten is most expensive area than others

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
df['revenue'] = (365-df['availability_365'])*df['price']
df['total_revenue'] = df.groupby('host_id')['revenue'].transform(sum)
df['average_revenue'] = df['total_revenue']/df['calculated_host_listings_count']

# %%
# The count of the 75% percentile hosts according to different room_type in different areas
df2 = df[df['average_revenue']>=df['average_revenue'].quantile(1)]
fig3 = sns.catplot(x='neighbourhood_group',data=df2,hue='room_type',kind='count',palette='CMRmap_r')
fig3.fig.suptitle('Who are the most successful hosts?',fontsize=15,y=1.05)
fig3.savefig('host.png', bbox_inches = 'tight')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to find whos is the most succesful hosts

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# as per above chart queens is most suvvesful host for private room and brooklyn is most sucssesfull host for entire home apartment

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#we can see from our statistical table that we have some extreme values, therefore we need to remove them for the sake of a better visualization

#creating a sub-dataframe with no extreme values / less than 500
sub_6=df[df.price < 500]
#using violinplot to showcase density and distribtuion of prices
viz_2=sns.violinplot(data=sub_6, x='neighbourhood_group', y='price')
viz_2.set_title('Density and distribution of prices for each neighberhood_group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to check the prices distribution for each neighbourhood

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# as per voilin plot manhatten is most expensive room than other host

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Which host_name is the most popular hosts between customers?
a=df.groupby(by=['host_name']).calculated_host_listings_count.mean()
a = a.sort_values(ascending=False)
print(a)

# %%
# Your code to calculate the mean of calculated_host_listings_count for each host and sort them
a = a.sort_values(ascending=False)

# Create a horizontal bar chart to visualize the average calculated_host_listings_count by host
plt.figure(figsize=(12, 6))
top_n = 10  # Change this to show the top N hosts
plt.barh(a.index[:top_n], a.values[:top_n], color='lightgreen')
plt.xlabel('Average Calculated Host Listings Count')
plt.ylabel('Host Name')
plt.title('Top {} Popular Hosts by Calculated Host Listings Count'.format(top_n))

# Display the chart
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to check which host is most popular host in customer

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# sonder is more popular host in customer

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#let's now combine this with our boroughs and room type for a rich visualization we can make

#grabbing top 10 neighbourhoods for sub-dataframe
sub_7=df.loc[df['neighbourhood'].isin(['Williamsburg','Bedford-Stuyvesant','Harlem','Bushwick',
                 'Upper West Side','Hell\'s Kitchen','East Village','Upper East Side','Crown Heights','Midtown'])]
#using catplot to represent multiple interesting attributes together and a count
viz_3=sns.catplot(x='neighbourhood', hue='neighbourhood_group', col='room_type', data=sub_7, kind='count')
viz_3.set_xticklabels(rotation=90)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This visualization can help you understand the popularity of different room types in specific neighborhoods

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# as per catplot manhatten has more private rooms , entire home apartment ,and shared room than brooklyn

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Check the correlation between numerical variables
df_new = df.drop(['name','host_name','neighbourhood','last_review','revenue','total_revenue','average_revenue'],axis=1)

# %%
corr = df_new.corr(method='kendall')
plt.figure(figsize=(13,10))
plt.title("Correlation Between Different Variables\n")
sns.heatmap(corr, annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To check the multicollinearity problem.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There’s correlation among host_id to reveiws_per_month & availability_365 (sequential color bar is used between value and color). Also there’s noticiable correlation between min_nights, no_of_listings_count & availability_365. Price also shows some correlation with availability_365 & host_listings_count.
#
# no_of_reviews and reviews_per_month gives almost the same information. so we can carry out analysis with any of the two variable. Also, no_of_reviews is correlated to availability_365!

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# Assuming you have a DataFrame named 'df' containing your Airbnb dataset

# Select the numerical columns you want to include in the pair plot
numerical_columns = ['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# Create a pair plot
sns.pairplot(df[numerical_columns], height=2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the pairwise relationship between variables within dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# Recomondation system is more effective to increse bussiness module. and give exciting offer to customer in holidays and weekends. give some discount offer in price other days that definately increase the bussiness

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.Manhattan is the most focused place in New York for hosts to do their business
#
# 2.Customers pay highest amount in Brooklyn,Queens and Manhattan that is 10,000 and lowest amount is 10$.
#
# 3.For the three types of room type (i.e. Entire home, Shared room, & Private room) average price of entire home is around $157, for shared room is around 60, and for private room is around 75.
#
# 4.'Entire home/apt' room type has the highest number of listing of 52% and ‘Shared Room’ is the least listed room type at only 2.4% in total.
#
# 5.People stay for longer duration of time in Private rooms in Brooklyn and Manhattan.
#
# 6.Count of listing by top 10 hosts is almost 2.5%(1270 listings) of the whole dataset. Top three host base on their turnover are Sonder(nyc),Red awning, Henry and best host is Sonder(nyc) More customer preferred Manhattan location for night stay then Brooklyn *63.2% customer spend night in Entire home and 1.6% spend night in Shared room

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
